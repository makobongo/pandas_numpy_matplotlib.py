# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
def historic_price(symbol, exchange='bitfinex', after='2020-09-01'):
    url = 'https://api.cryptowat.ch/markets/{exchange}/{symbol}usd/ohlc'.format(symbol=symbol,exchange=exchange)
    resp = requests.get(url, params={
        'periods':'3600',
        'after':str(int(pd.Timestamp(after).timestamp()))
    })
    resp.raise_for_status()
    data = resp.json()
    df = pd.DataFrame(data['result']['3600'], columns=['CloseTime','OpenPrice','HighPrice','LowPrice','ClosePrice','Volume','NA'])
    df['CloseTime'] = pd.to_datetime(df['CloseTime'], unit='s')
    df.set_index('CloseTime', inplace=True)
    return df

# %%
last_week = (pd.Timestamp.now() - pd.offsets.Day(7))
last_week
# Out:
# Timestamp('2020-12-23 09:00:59.801475')

# %%
btc = historic_price('btc', 'bitstamp', after=last_week)

# %%
eth = historic_price('eth', 'bitstamp', after=last_week)

# %% [markdown]
# #### Bitcoin

# %%
btc.head()
# Out:
#                      OpenPrice  HighPrice  LowPrice  ClosePrice      Volume  \
# CloseTime
# 2020-12-22 17:00:00   23359.06   23456.20  23229.04    23358.58  428.468438
# 2020-12-22 18:00:00   23356.70   23435.64  23225.99    23335.94  241.300188
# 2020-12-22 19:00:00   23343.10   23524.21  23343.10    23436.63  264.737936
# 2020-12-22 20:00:00   23432.63   23515.35  23327.20    23408.80  345.401701
# 2020-12-22 21:00:00   23416.31   23454.98  23282.47    23440.85  529.240934
#
#                                NA
# CloseTime
# 2020-12-22 17:00:00  1.000857e+07
# 2020-12-22 18:00:00  5.631475e+06
# 2020-12-22 19:00:00  6.206235e+06
# 2020-12-22 20:00:00  8.096825e+06
# 2020-12-22 21:00:00  1.238167e+07

# %%
btc['ClosePrice'].plot(kind='line', figsize=(15,7))

# %% [markdown]
# #### Etherium

# %%
eth.head()
# Out:
#                      OpenPrice  HighPrice  LowPrice  ClosePrice        Volume  \
# CloseTime
# 2020-12-22 17:00:00     626.88     633.73    622.33      627.64  13519.826992
# 2020-12-22 18:00:00     628.06     629.76    623.75      627.28   6464.504859
# 2020-12-22 19:00:00     628.22     629.02    625.84      627.87    825.949868
# 2020-12-22 20:00:00     629.12     630.17    624.01      626.70    759.794002
# 2020-12-22 21:00:00     626.23     627.76    622.40      624.73   6880.779132
#
#                                NA
# CloseTime
# 2020-12-22 17:00:00  8.492709e+06
# 2020-12-22 18:00:00  4.051327e+06
# 2020-12-22 19:00:00  5.179765e+05
# 2020-12-22 20:00:00  4.764230e+05
# 2020-12-22 21:00:00  4.294157e+06

# %%
eth['ClosePrice'].plot(kind="line", figsize=(15,7))

# %%
# %time 45*3
# Out:
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 10 µs
# 135

# %%
import pandas as pd

mal = pd.read_csv('malaria.csv')
# obtaining only ten records
rec = mal[0:4]
# dropping null values
rec2 = rec.fillna(0)
rec2
# Out:
#        Country  Year              No. of cases      No. of deaths  \
# 0  Afghanistan  2017     630308[495000-801000]       298[110-510]
# 1      Algeria  2017                         0                  0
# 2       Angola  2017  4615605[3106000-6661000]  13316[9970-16600]
# 3    Argentina  2017                         0                  0
#
#    No. of cases_median  No. of cases_min  No. of cases_max  \
# 0               630308          495000.0          801000.0
# 1                    0               0.0               0.0
# 2              4615605         3106000.0         6661000.0
# 3                    0               0.0               0.0
#
#    No. of deaths_median  No. of deaths_min  No. of deaths_max  \
# 0                   298              110.0              510.0
# 1                     0                0.0                0.0
# 2                 13316             9970.0            16600.0
# 3                     0                0.0                0.0
#
# ...

# %%
data = {
    'Sex':['M','F','F','M','D','?'],
    'Count':[20,30,10,15,11,19]
}
j = pd.DataFrame(data)
# print(j['Sex'].unique())
# print(j['Sex'].value_counts())
# print(j['Sex'].replace('D','F'))
j[j['Sex']=='M']
# Out:
#   Sex  Count
# 0   M     20
# 3   M     15

# %%
d = {
    'ambassordors':['John Benoit', 'Phillip Otwell', 'Maxwell Rigde', 'Autumn Dosch', 'Mat Kaltenberger','Philip Suarez'],
    'countries':['France', 'United Kingdom', 'United Kingdom', 'Germany', 'Germany', 'Germany']
}
b = pd.DataFrame(d)
# b[b['countries'].duplicated()]
b
# Out:
#        ambassordors       countries
# 0       John Benoit          France
# 1    Phillip Otwell  United Kingdom
# 2     Maxwell Rigde  United Kingdom
# 3      Autumn Dosch         Germany
# 4  Mat Kaltenberger         Germany
# 5     Philip Suarez         Germany

# %%
df = pd.DataFrame({'Data':['1887_M_US_1','1990?_M_UK_1','1992_F_US_2','1992?_M _IT_1','1985_F_IT_2']})

# %%
df['Data'].str.split('_')
# Out:
# 0      [1887, M, US, 1]
# 1     [1990?, M, UK, 1]
# 2      [1992, F, US, 2]
# 3    [1992?, M , IT, 1]
# 4      [1985, F, IT, 2]
# Name: Data, dtype: object

# %%
df['Data'].str.split('_', expand=True)
# Out:
#        0   1   2  3
# 0   1887   M  US  1
# 1  1990?   M  UK  1
# 2   1992   F  US  2
# 3  1992?  M   IT  1
# 4   1985   F  IT  2

# %%
pd.read_csv('test2.csv', sep='>')
# Out:
#       0  1   2  3
# 0  1887  M  US  1
# 1  1990  M  UK  1
# 2  1992  F  US  2
# 3  1992  M  IT  1
# 4  1985  F  IT  2

# %%
import pymysql
with open('hoh.sql') as sql:
    sq = sql.read()
#     print(sq)
conn = pymysql.connect("localhost","root","makobongo","hoh")
cursor = conn.cursor()
cursor.execute('SELECT * FROM users')
pd.DataFrame(cursor.fetchall(), index=None,columns=['id', 'name', 'role', 'email', 'reg', 'pass', 'y', 'na', 'ph','k', 'd'])
# Out:
#     id                   name   role                          email  \
# 0    1            john osteve   user              rrice@example.org
# 1    2             osteve mac  admin               osteve@gmail.com
# 2    3    Prof. Jude Nikolaus   user              jkoss@example.net
# 3    4      Juanita Buckridge   user            bcasper@example.org
# 4    5          Maxwell Klein   user     danielle.ratke@example.org
# ..  ..                    ...    ...                            ...
# 57  58       Marlene Frami IV   user  allan.oberbrunner@example.org
# 58  59           Price Maggio   user        jerel.lynch@example.com
# 59  60        Keshawn Rolfson   user     carley.gutmann@example.net
# 60  61    Mr. Lucious Denesik   user    corwin.cordelia@example.org
# 61  62  Mr. Jamir Tillman III   user   emanuel.ondricka@example.net
#
#                    reg                                               pass  \
# 0  2020-08-22 07:12:36  $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og...
# ...

# %%
import pymysql
conn = pymysql.connect("localhost","root","makobongo", "hoh")
rd = pd.read_sql('SELECT * FROM users', conn)
rd
# Out:
#     id                   name   role                          email  \
# 0    1            john osteve   user              rrice@example.org
# 1    2             osteve mac  admin               osteve@gmail.com
# 2    3    Prof. Jude Nikolaus   user              jkoss@example.net
# 3    4      Juanita Buckridge   user            bcasper@example.org
# 4    5          Maxwell Klein   user     danielle.ratke@example.org
# ..  ..                    ...    ...                            ...
# 57  58       Marlene Frami IV   user  allan.oberbrunner@example.org
# 58  59           Price Maggio   user        jerel.lynch@example.com
# 59  60        Keshawn Rolfson   user     carley.gutmann@example.net
# 60  61    Mr. Lucious Denesik   user    corwin.cordelia@example.org
# 61  62  Mr. Jamir Tillman III   user   emanuel.ondricka@example.net
#
#      email_verified_at                                           password  \
# 0  2020-08-22 07:12:36  $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og...
# ...

# %%
j = pd.read_csv('malaria.csv').head()
j.fillna(0)
# Out:
#        Country  Year              No. of cases      No. of deaths  \
# 0  Afghanistan  2017     630308[495000-801000]       298[110-510]
# 1      Algeria  2017                         0                  0
# 2       Angola  2017  4615605[3106000-6661000]  13316[9970-16600]
# 3    Argentina  2017                         0                  0
# 4      Armenia  2017                         0                  0
#
#    No. of cases_median  No. of cases_min  No. of cases_max  \
# 0               630308          495000.0          801000.0
# 1                    0               0.0               0.0
# 2              4615605         3106000.0         6661000.0
# 3                    0               0.0               0.0
# 4                    0               0.0               0.0
#
#    No. of deaths_median  No. of deaths_min  No. of deaths_max  \
# 0                   298              110.0              510.0
# 1                     0                0.0                0.0
# ...

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)')
dfs[4].to_csv('gdpOf.csv', index=False)

# %%
df = dfs[3]
df.to_csv('gdp.csv', index=False)

# %%
import requests
r = requests.get('https://www.topuniversities.com/student-info/choosing-university/worlds-top-100-universities')
r.status_code
j = pd.read_html(r.text)[0]
j.to_csv(header=None, index=F)
# Out:
# '0,Rank,University,Location\n1,1,Massachusetts Institute of Technology (MIT),United States\n2,2,Stanford University,United States\n3,3,Harvard University,United States\n4,4,California Institute of Technology (Caltech),United States\n5,5,University of Oxford,United Kingdom\n6,6,ETH Zurich (Swiss Federal Institute of Technology),Switzerland\n7,7,University of Cambridge,United Kingdom\n8,8,Imperial College London,United Kingdom\n9,9,University of Chicago,United States\n10,10,UCL (University College London),United Kingdom\n11,11,National University of Singapore (NUS),Singapore\n12,12,Princeton University,United States\n13,13,"Nanyang Technological University, Singapore (NTU)",Singapore\n14,14,Ecole Polytechnique Fédérale de Lausanne (EPFL),Switzerland\n15,15,Tsinghua University,China\n16,16,University of Pennsylvania,United States\n17,18,Yale University,United States\n18,17,Cornell University,United States\n19,19,Columbia University,United States\n20,20,University of Edinburgh,United Kin
# ...

# %%
j = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2020_per_game.html')
j[0].head(10)
# Out:
#    Rk                    Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0   1              Steven Adams   C  26  OKC  63  63  26.7  4.5   7.6  ...
# 1   2               Bam Adebayo  PF  22  MIA  72  72  33.6  6.1  11.0  ...
# 2   3         LaMarcus Aldridge   C  34  SAS  53  53  33.1  7.4  15.0  ...
# 3   4            Kyle Alexander   C  23  MIA   2   0   6.5  0.5   1.0  ...
# 4   5  Nickeil Alexander-Walker  SG  21  NOP  47   1  12.6  2.1   5.7  ...
# 5   6             Grayson Allen  SG  24  MEM  38   0  18.9  3.1   6.6  ...
# 6   7             Jarrett Allen   C  21  BRK  70  64  26.5  4.3   6.6  ...
# 7   8              Kadeem Allen  PG  27  NYK  10   0  11.7  1.9   4.4  ...
# 8   9           Al-Farouq Aminu  PF  29  ORL  18   2  21.1  1.4   4.8  ...
# 9  10           Justin Anderson  SG  26  BRK  10   1  10.7  1.0   3.8  ...
#
#     FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  .582  3.3  6.0   9.3  2.3  0.8  1.1  1.5  1.9  10.9
# ...

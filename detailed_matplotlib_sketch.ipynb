# %% [markdown]
# ### Ensure you start  by compiling the first cell to ensure necessary packages are imported

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25], 'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.plot([1,2,3,4],[1,4,9,16], 'ro')

# %% [markdown]
# ####  Changing the thickness of the lines

# %%
plt.plot([1,2,4,2,1,0,1,2,1,4],linewidth=2.0)

# %%
t = np.arange(0,5,0.1)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)
plt.subplot(211)
plt.plot(t,y1,'b-.')
plt.subplot(212)
plt.plot(t,y2,'r--')

# %%
t = np.arange(0.,1.,0.05)
y1 = np.sin(2*np.pi*t)
y2 = np.cos(2*np.pi*t)
plt.subplot(121)
plt.plot(t,y1,'b-.')
plt.subplot(122)
plt.plot(t,y2,'r--')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='serif')
plt.xlabel('Counting', color='grey')
plt.ylabel('Square Values', color='grey')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1,12, r'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.2})
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['First series','Second series','Third series'],loc=2)
plt.savefig('my_chart.png')

# %%
# %save plot_img 188
# Out:
# File `plot_img.py` exists. Overwrite (y/[N])?  y
# The following commands were written to file `plot_img.py`:
# plt.axis([0,5,0,20])
# plt.title('My first plot',fontsize=20,fontname='serif')
# plt.xlabel('Counting', color='grey')
# plt.ylabel('Square Values', color='grey')
# plt.text(1,1.5,'First')
# plt.text(2,4.5,'Second')
# plt.text(3,9.5,'Third')
# plt.text(4,16.5,'Fourth')
# plt.text(1,12, r'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.2})
# plt.grid(True)
# plt.plot([1,2,3,4],[1,4,9,16],'ro')
# plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
# plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
# plt.legend(['First series','Second series','Third series'],loc=2)

# %% [markdown]
# #### Handling dates

# %%
import datetime
events = [datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.date(2015,2,3),datetime.date(2015,2,21),datetime.date(2015,3,15),datetime.date(2015,3,24),datetime.date(2015,4,8),datetime.date(2015,4,24)]
readings = [12,22,25,20,18,15,17,14]
plt.plot(events,readings)

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%Y-%m')
events = [datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.date(2015,2,3),datetime.date(2015,2,21),datetime.date(2015,3,15),datetime.date(2015,3,24),datetime.date(2015,4,8),datetime.date(2015,4,24)]
readings = [12,22,25,20,18,15,17,14]
fig, ax = plt.subplots()
plt.plot(events,readings)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
y = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(1*x)/x
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
y = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(1*x)/x
plt.plot(x,y,'k--',linewidth=3)
plt.plot(x,y2,'m-.')
plt.plot(x,y3,color='#87a3cc', linestyle='--')

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
y = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(1*x)/x
plt.plot(x,y,'k--',linewidth=3)
plt.plot(x,y2,'m-.')
plt.plot(x,y3,color='#87a3cc', linestyle='--')
plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],[r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])
plt.yticks([-1,0,+1,+2,+3],[r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f48c2af3810>,
# ...
#  <a list of 5 Text yticklabel objects>)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-2*np.pi,2*np.pi,0.01)
y = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(x)/x
plt.plot(x,y,color='b')
plt.plot(x,y2,color='r')
plt.plot(x,y3,color='g')
plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
[r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])
plt.yticks([-1,0,+1,+2,+3],
[r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-2*np.pi,2*np.pi,0.01)
y = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(x)/x
plt.plot(x,y,color='b')
plt.plot(x,y2,color='r')
plt.plot(x,y3,color='g')
plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],[r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])
plt.yticks([-1,0,+1,+2,+3],[r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])
plt.annotate(r'$\lim_{x\to 0}\frac{\sin(x)}{x}= 1$',xy=[0,1],xycoords='data',xytext=[30,30],fontsize=16,textcoords='offset points',arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=.2"))
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %% [markdown]
# #### Line graph

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = np.arange(5)
data = {
    'Series1':[1,3,4,3,5],
    'Series2':[2,4,5,2,4],
    'Series3':[3,2,3,1,3]
}
df = pd.DataFrame(data)
plt.axis([0,5,0,7])
plt.plot(x,df)
plt.legend(data, loc=2)

# %% [markdown]
# #### Histogram graph

# %%
import matplotlib.pyplot as plt
import numpy as np
pop = np.random.randint(0,100,100)
n,bins,patches = plt.hist(pop,bins=20)

# %%
import matplotlib.pyplot as plt
index = [0,1,2,3,4]
values = [5,7,3,4,6]
plt.bar(index,values)
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
index = [0,1,2,3,4]
values = [5,7,3,4,6]
plt.bar(index,values)
plt.xticks(index,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f48c1fcd790>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
import numpy as np
index = np.arange(5)
values1 = [5,7,3,4,6]
std1 = [0.8,1,0.4,0.9,1.3]
plt.title('A Bar Chart')
plt.bar(index,values1,yerr=std1,error_kw={'ecolor':'0.1','capsize':6},alpha=0.7,label='First')
plt.xticks(index+0.4,['A','B','C','D','E'])
plt.legend(loc=2)

# %% [markdown]
# #### Horizontal Bar

# %%
import matplotlib.pyplot as plt
index = [0,1,2,3,4]
values = [5,7,3,4,6]
plt.xlabel('X values')
plt.ylabel('Y values')
plt.barh(index,values, label='First')
plt.yticks(index, ['A', 'B', 'C', 'D', 'E'])
plt.legend(loc=5)

# %% [markdown]
# #### Multiserial Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.arange(5)
values1 = [5,7,3,4,6]
values2 = [6,6,4,5,7]
values3 = [5,6,5,4,6]
bw = 0.3
plt.axis([0,6,0,8])
plt.title('A Multiseries Bar Chart',fontsize=20)
plt.bar(index+1.0,values1,bw,color='b')
plt.bar(index+bw+1.0,values2,bw,color='g')
plt.bar(index+2*bw+1.0,values3,bw,color='r')
plt.xticks(index+1.3,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f48c1006d10>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.arange(5)
values1 = [5,7,3,4,6]
values2 = [6,6,4,5,7]
values3 = [5,6,5,4,6]
bw=0.3
plt.barh(index, values1,bw)
plt.barh(index+0.3, values2,bw)
plt.barh(index+0.6, values3,bw)
plt.yticks(index,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f48c0956ad0>,
# ...
#  <a list of 5 Text yticklabel objects>)

# %% [markdown]
# #### Multiseries Bar Chart with pandas DataFrame

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,3]
}
df = pd.DataFrame(data)
df.plot(kind='bar')

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,3]
}
df = pd.DataFrame(data)
df.plot(kind='barh')

# %% [markdown]
# #### Multiseries Stacked Bar Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

index = np.arange(4)
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
plt.axis([0,4,0,15])
plt.bar(index+0.5, series1, color='r')
plt.bar(index+0.5, series2, color='b', bottom=series1)
plt.bar(index+0.5, series3, color='g', bottom=series1+series2)
plt.xticks(index+0.5,['Jan15','Feb15','Mar15','Apr15'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f48c00e4bd0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.arange(4)
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
plt.axis([0,15,0,4])
plt.title('A Multiseries Horizontal Stacked Bar Chart')
plt.barh(index+0.5,series1,color='r')
plt.barh(index+0.5,series2,color='g', left=series1)
plt.barh(index+0.5,series3,color='b', left=series1+series2)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.arange(4)
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
plt.axis([0,15,0,4])
plt.title('A Multiseries Horizontal Stacked Bar Chart')
plt.barh(index,series1,color='w',hatch='xx')
plt.barh(index,series2,color='w',hatch='///', left=series1)
plt.barh(index,series3,color='w',hatch='\\\\\\',left=(series1+series2))
plt.yticks(index+0.4,['Jan15','Feb15','Mar15','Apr15'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f48bfa425d0>,
# ...
#  <a list of 4 Text yticklabel objects>)

# %% [markdown]
# #### Stacked Bar Charts with pandas DataFrame

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,3]
}
df = pd.DataFrame(data)
df.plot(kind='bar', stacked=True)

# %% [markdown]
# #### Pie Charts

# %%
import matplotlib.pyplot as plt
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
plt.pie(values,labels=labels,colors=colors)
plt.axis('equal')
# Out:
# (-1.11637372803214,
#  1.1007797090739162,
#  -1.1163737124158366,
#  1.1007797083302826)
